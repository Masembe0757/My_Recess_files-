# %%
import pandas as pd

# %%
df4 = pd.read_csv("bse_dataset4.csv")
df4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
df4.shape
# Out:
# (169, 15)

# %%
df4.columns
# Out:
# Index(['Timestamp', 'gender', 'Age', 'emotion', 'YOB', 'CGPA',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? ', 'Duration',
#        'Pulse', 'Maxpulse', 'Calories'],
#       dtype='object')

# %%
#checking the datatype of each column
df4.dtypes
# Out:
# Timestamp                                              object
# gender                                                 object
# Age                                                   float64
# emotion                                                object
# YOB                                                    object
# CGPA                                                   object
# Do you have a Girl Friend or BOY Friend                object
# Do you have Depression?                                object
# Do you have Anxiety?                                   object
# Do you have Panic attack?                              object
# Did you have seek any specialist for a treatment?      object
# Duration                                                int64
# Pulse                                                   int64
# Maxpulse                                                int64
# Calories                                              float64
# dtype: object

# %%
#checking for unique values of each column
df4.nunique()
# Out:
# Timestamp                                              93
# gender                                                 10
# Age                                                    14
# emotion                                                52
# YOB                                                    19
# CGPA                                                   63
# Do you have a Girl Friend or BOY Friend                14
# Do you have Depression?                                13
# Do you have Anxiety?                                   18
# Do you have Panic attack?                              13
# Did you have seek any specialist for a treatment?       9
# Duration                                               16
# Pulse                                                  47
# Maxpulse                                               57
# Calories                                              141
# dtype: int64

# %%
#Taking random samples from the dataset
df4.sample(10)
# Out:
#                Timestamp   gender   Age     emotion   YOB  CGPA  \
# 40   05/07/2023 09:40:42  Female   20.0       Tired  2002   1.3
# 61   05/07/2023 09:41:40     Male  21.0         Sad  2002  4.46
# 47   05/07/2023 09:41:05  Female   22.0       Anger  2001   4.1
# 92   05/07/2023 09:53:56  Female   68.0         Sad  1953   4.8
# 117  05/07/2023 09:40:16   FEMALE  19.0       HAPPY  2004   2.1
# 162  05/07/2023 09:43:36     male  21.0    stressed  2002   4.4
# 103  05/07/2023 09:39:49   female  21.0  irritated   2001  3.88
# 120  05/07/2023 09:40:27     male  20.0        calm  2002   3.7
# 41   05/07/2023 09:40:46     male  21.0       happy  2001  4.65
# 0    05/07/2023 09:38:39     Male  21.0     Content  2002  4.22
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# 40                                       No                      No
# 61                                       No                Probably
# ...

# %%
#Converting age to float
#df4.Age.astype(float)

# %%
#checking for numerical fields
df4.select_dtypes(include=["number"]).columns.tolist()
# Out:
# ['Age', 'Duration', 'Pulse', 'Maxpulse', 'Calories']

# %%
#quick static report for numerical data
df4.describe()
# Out:
#               Age    Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000  169.000000   164.000000
# mean    22.497006   63.846154  107.449704  134.071006   375.901829
# std      4.921859   42.299949   14.517195   16.432971   266.331026
# min     19.000000   15.000000   80.000000  100.000000    50.300000
# 25%     21.000000   45.000000  100.000000  124.000000   252.725000
# 50%     21.000000   60.000000  105.000000  131.000000   318.600000
# 75%     22.000000   60.000000  111.000000  141.000000   387.600000
# max     68.000000  300.000000  159.000000  184.000000  1860.400000

# %%
#checking for categorical fields
df4.select_dtypes(include=["object"]).columns.tolist()
# Out:
# ['Timestamp',
#  'gender',
#  'emotion',
#  'YOB',
#  'CGPA',
#  'Do you have a Girl Friend or BOY Friend',
#  'Do you have Depression?',
#  'Do you have Anxiety?',
#  'Do you have Panic attack?',
#  'Did you have seek any specialist for a treatment? ']

# %%
#checking correlation with respect to a specific target such as how other field varry with CGPA
#df4.corr()["CGPA"]

# %%
#droping duplicates in a particular column
#df4.drop_duplictes(subset=["Age"])

# %% [markdown]
# # Outliers using quartiles

# %%
lower_limit = df4["Age"].quantile(0.05) #5%
lower_limit
# Out:
# 20.0

# %%
upper_limit = df4["Age"].quantile(0.95) #95%
upper_limit
# Out:
# 28.0

# %%
#Displaying records below lower limit
df4[df4["Age"]<lower_limit]
# Out:
#                Timestamp  gender   Age emotion   YOB CGPA  \
# 20   05/07/2023 09:39:54  FEMALE  19.0   HAPPY  2004  2.1
# 49   05/07/2023 09:41:07    Male  19.0   angry  2004  2.5
# 117  05/07/2023 09:40:16  FEMALE  19.0   HAPPY  2004  2.1
# 149  05/07/2023 09:41:47  FEMALE  19.0   HAPPY  2004  2.1
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# 20                                      YES                   MAYBE
# 49                                       no                    none
# 117                                     YES                   MAYBE
# 149                                     YES                   MAYBE
#
#     Do you have Anxiety? Do you have Panic attack?  \
# 20                   YES                        NO
# 49                  none                      none
# 117                  YES                        NO
# 149                  YES                        NO
#
# ...

# %%
#Displaying records above uppper limit
df4[df4["Age"]>upper_limit]
# Out:
#               Timestamp         gender   Age    emotion         YOB  \
# 1   05/07/2023 09:38:57  Marabou stock  45.0      Weird        2100
# 48  05/07/2023 09:41:06           Male  50.0        Sad        1970
# 67  05/07/2023 09:41:58           Male  30.0        Sad  18/11/1993
# 92  05/07/2023 09:53:56        Female   68.0        Sad        1953
# 93  05/07/2023 09:54:13           Male  29.0    Hopeful        1994
# 96  05/07/2023 09:54:52           male  30.0     hunger        2023
# 97  05/07/2023 09:56:37         Female  29.0  Grateful         2002
#
#                 CGPA Do you have a Girl Friend or BOY Friend  \
# 1                8.9                                     Yes
# 48                 5                                      No
# 67               2.5                                     yes
# 92               4.8                                      No
# 93  I don't know yet              Sure, multiple girlfriends
# ...

# %%
#EXcluding outliers#Displaying records below lower limit

df4_without_outliers = df4[(df4["Age"]>lower_limit) & (df4["Age"]< upper_limit)]
df4_without_outliers
# Out:
#                Timestamp  gender   Age     emotion   YOB  CGPA  \
# 0    05/07/2023 09:38:39    Male  21.0     Content  2002  4.22
# 3    05/07/2023 09:39:12    Male  21.0       Happy  2003  4.37
# 4    05/07/2023 09:39:14  Female  21.0       Happy  2002  3.63
# 5                    NaN  Female  23.0      Happy   2000   3.8
# 6    05/07/2023 09:39:21  female  21.0  irritated   2001  3.88
# ..                   ...     ...   ...         ...   ...   ...
# 162  05/07/2023 09:43:36    male  21.0    stressed  2002   4.4
# 163  05/07/2023 09:43:56    Male  21.0     Relaxed  2001   4.5
# 164  05/07/2023 09:44:09    Male  22.0      Angry   1999   3.5
# 165  05/07/2023 09:44:14    male  23.0         sad  1999     4
# 167  05/07/2023 09:44:35  Female  21.0         sad  2001   3.8
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# 0                                        No                      No
# 3                                        No                      No
# ...

# %% [markdown]
# # Loc

# %%
#loc
#df4.loc[3,"Age"] = 25
# for age at row 3 in age column replace it with 25

# %%
#for x in df4.index:
#    if df4.loc[x,"Age"] == 21:
#        df4.loc[x,"Age"] = 5
#df4
#For every age that is equivalent to 21 , change it to 5

# %% [markdown]
# # NULLS

# %%
df4.isnull().sum()
# Out:
# Timestamp                                             1
# gender                                                0
# Age                                                   0
# emotion                                               1
# YOB                                                   0
# CGPA                                                  0
# Do you have a Girl Friend or BOY Friend               0
# Do you have Depression?                               0
# Do you have Anxiety?                                  0
# Do you have Panic attack?                             0
# Did you have seek any specialist for a treatment?     0
# Duration                                              0
# Pulse                                                 0
# Maxpulse                                              0
# Calories                                              5
# dtype: int64

# %%
df4_new = df4.fillna(method ="ffill")
df4_new
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
df4_new["Calories"]
# Out:
# 0      409.1
# 1      479.0
# 2      340.0
# 3      282.4
# 4      406.0
#        ...
# 164    290.8
# 165    300.0
# 166    310.2
# 167    320.4
# 168    330.4
# Name: Calories, Length: 169, dtype: float64

# %%
#replacing nulls in age with general mean
m = df4["Age"].mean()
print(m)
df5 = df4["Age"].fillna(m,inplace = True)
df4
# Out:
# 22.49700598802395
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
#Filling using median
med = df4["Age"].median()
print(med)
df4["Age"].fillna(med,inplace = True)
df4
# Out:
# 21.0
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
#Use mode for Age nulls
mod = df4["Age"].mode()
print(mod)
df4["Age"].fillna(mod,inplace = True)
df4
# Out:
# 0    21.0
# Name: Age, dtype: float64
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %% [markdown]
# # WRONG FORMATS

# %%
#Data that has a wrong type in reference to the other data in the given column

# %% [markdown]
# # WRONG DATA

# %%
#Majory data out of normalo føow or outlier

# %% [markdown]
# # DUPLICATES
