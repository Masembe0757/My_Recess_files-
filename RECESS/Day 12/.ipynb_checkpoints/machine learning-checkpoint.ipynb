# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mt
import seaborn as sns
import sklearn as sk

# %%
data = pd.read_csv("heart_disease.csv")
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
#Bar plot showing heart disease frequency of age
pd.crosstab(data.age,data.target).plot(kind = 'bar',figsize = (20,6))
plt.title('Heart diseases frequency against age')
plt.ylabel('age')
plt.xlabel('age')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 #Bar plot showing heart disease frequency of age
#       2 pd.crosstab(data.age,data.target).plot(kind = 'bar',figsize = (20,6))
# ----> 3 plt.title('Heart diseases frequency against age')
#       4 plt.ylabel('age')
#       5 plt.xlabel('age')
#
# TypeError: 'str' object is not callable

# %%
#Bar plot showing heart disease frequency of sex
pd.crosstab(data.sex,data.target).plot(kind = 'bar',figsize = (20,6))
plt.xticks(rotation = 0)
plt.ylabel('frequency')
plt.xlabel('sex')
plt.title('Heart diseases frequency against sex')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 4
#       2 pd.crosstab(data.sex,data.target).plot(kind = 'bar',figsize = (20,6))
#       3 plt.xticks(rotation = 0)
# ----> 4 plt.ylabel('frequency')
#       5 plt.xlabel('sex')
#       6 plt.title('Heart diseases frequency against sex')
#
# TypeError: 'str' object is not callable
